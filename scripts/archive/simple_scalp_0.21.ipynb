# %%
from IPython.core.display import HTML
from IPython.display import display, clear_output

display(HTML("<style>.output_subarea { overflow: auto; }</style>"))

import datetime
import random
import os
import pandas as pd
import socket

from supabase import create_client, Client
from ib_async import *

import urllib

hostname = socket.gethostname()
util.logToFile(f"{datetime.datetime.now().strftime('%Y-%m-%d')}-{hostname}.log")
util.startLoop()
util.logToConsole()

if "ib" in globals():
    ib.disconnect()

randint = lambda a=1, b=10: random.randint(a, b)
ib = IB()
ib.connect("127.0.0.1", 4001, randint(1, 99))

# connect to supabase server
url: str = "https://dbcizmxdlufqncxipqwt.supabase.co"
key: str = (
    "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6ImRiY2l6bXhkbHVmcW5jeGlwcXd0Iiwicm9sZSI6ImFub24iLCJpYXQiOjE3MDE4NDkxMTMsImV4cCI6MjAxNzQyNTExM30.ys98bhleekrfDJAbrMMqXGsVh1XMa3Vtl8O62s7D5as"
)
supabase: Client = create_client(url, key)

import platform

if platform.system() == "Linux":
    import chime


def chime_success():
    if platform.system() == "Linux":
        chime.success()


chime_success()
os.system("say beep")

# setup listeners for ib
# NQM2024 contract
print("Setting contract to NQM2024 symbol / JUN 2024 / Contract(conId=620730920)")
contract = Contract(conId=620730920)
ib.qualifyContracts(contract)

ticker = ib.reqMktDepth(contract)

ib.reqPositions()
ib.reqAccountSummary()
allopenorders = ib.reqAllOpenOrders()
executions = ib.reqExecutions()

ib.accountSummary()
ib.accountValues()
ib.accountValueEvent()


def push_notifications(msg="Hello world!"):
    try:
        body = f"[{datetime.datetime.now()}] {msg}"
        print(body)
        data = urllib.parse.urlencode({"text": body}).encode()
        req = urllib.request.Request(
            "https://api.chanify.net/v1/sender/CICswLUGEiJBQUZIR0pJQ0VVNkxUTlZCMk1DRElCWU1RSlNWMktCS0NFIgIIAQ.vj8gcfxM4jD9Zv0mBMSlFlY51EL_jC5dB8LWdWX1tAs",
            data=data,
        )
        response = urllib.request.urlopen(req)
        response.read()  # Read the response to ensure the request is complete
    except urllib.error.URLError as e:
        print(f"Error sending request: {e.reason}")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")


def print_reqOpenOrders():
    print("Session Orders::")
    display(util.df([t.order for t in ib.reqOpenOrders()]))


def print_reqAllOpenOrders():
    print("All Session Orders:")
    display(util.df([t.order for t in ib.reqAllOpenOrders()]))


def print_account_summary(ib):
    print("ACCOUNT SUMMARY::\n")
    acct_fields = ib.accountSummary(account="U10394496")

    for f in acct_fields:
        if "DayTrades" not in f.tag:
            print(f.tag, ":", f.value)
    print()


def print_order(o):
    if o is None:
        print()
        return

    order = o.order
    contract = o.contract
    orderStatus = o.orderStatus

    print(f"symbol\tpermId\t\tstatus\t\taction\tfilled\tremaining\tlmtPrice")

    print(
        f"{contract.symbol}\t{order.permId}\t{orderStatus.status}\t{order.action}\t{orderStatus.filled}\t{orderStatus.remaining}\t\t{order.lmtPrice}\t"
    )


def print_orderbook():
    print("NQ Order Book::")
    if ticker is not None and ticker.domBids is not None and ticker.domAsks is not None:
        for i in range(min(len(ticker.domBids), len(ticker.domAsks))):
            bid_size = ticker.domBids[i].size
            bid_price = ticker.domBids[i].price
            ask_price = ticker.domAsks[i].price
            ask_size = ticker.domAsks[i].size
            print(f"{bid_size:>8} {bid_price:>10} | {ask_price:<10} {ask_size:<8}")

    print()


def print_executions():
    fills = [t.fills for t in ib.trades() if t.fills != []]
    executions = [f[0].execution for f in fills]
    print(f"Intraday Executions: {len(executions)}\n")


def print_positions():
    print("POSITIONS::")
    future = [pos for pos in ib.positions()]
    for f in future:
        print(
            f"{f.contract.symbol} {f.position} @ {f.avgCost/float(contract.multiplier)}"
        )
    print()


def print_summary():
    print_orderbook()
    print_executions()

    print_positions()
    print_account_summary(ib=ib)


def print_openOrders(status_list=["Submitted", "PendingSubmit", "PendingCancel"]):
    print(":: openOrders ::")
    display(util.df([t for t in ib.openOrders()]))


def print_submittedtrades():
    print(":: trades ::")
    display(
        util.df(
            [
                t.order
                for t in ib.trades()
                if t.orderStatus.status == "Submitted"
                or t.orderStatus.status == "PreSubmitted"
                or t.orderStatus.status == "PendingSubmit"
            ]
        )
    )


print_summary()

print_submittedtrades()
# Out:
# <style>.output_subarea { overflow: auto; }</style>
# 2024-05-23 14:41:16,971 ib_async.ib INFO Disconnecting from 127.0.0.1:4001, 145 B sent in 9 messages, 170 kB received in 1436 messages, session time 87.4 s.
# 2024-05-23 14:41:16,977 ib_async.client INFO Disconnecting
# 2024-05-23 14:41:16,981 ib_async.client INFO Disconnected.
# 2024-05-23 14:41:16,988 ib_async.client INFO Connecting to 127.0.0.1:4001 with clientId 40...
# 2024-05-23 14:41:16,996 ib_async.client INFO Connected
# 2024-05-23 14:41:17,026 ib_async.client INFO Logged on to server version 176
# 2024-05-23 14:41:17,073 ib_async.wrapper INFO Warning 2104, reqId -1: Market data farm connection is OK:usfuture
# 2024-05-23 14:41:17,075 ib_async.wrapper INFO Warning 2104, reqId -1: Market data farm connection is OK:usfarm
# 2024-05-23 14:41:17,084 ib_async.wrapper INFO Warning 2107, reqId -1: HMDS data farm connection is inactive but should be available upon demand.ushmds
# 2024-05-23 14:41:17,088 ib_async.wrapper INFO Warning 2158, reqId -1: Sec-def data farm connection is OK:secdefil
# 2024-05-23 14:41:17,093 ib_async.client INFO API connection ready
# 2024-05-23 14:41:17,116 ib_async.wrapper INFO position: Position(account='U2340948', contract=Stock(conId=4762, symbol='BA', exchange='NYSE', currency='USD', localSymbol='BA', tradingClass='BA'), position=254.0, avgCost=203.21112205)
# 2024-05-23 14:41:17,150 ib_async.wrapper INFO position: Position(account='U10394496', contract=Option(conId=637079300, symbol='HYG', lastTradeDateOrContractMonth='20240621', strike=73.0, right='P', multiplier='100', currency='USD', localSymbol='HYG   240621P00073000', tradingClass='HYG'), position=50.0, avgCost=12.44685)
# 2024-05-23 14:41:17,156 ib_async.wrapper INFO position: Position(account='U10394496', contract=Option(conId=682674010, symbol='AAPL', lastTradeDateOrContractMonth='20241018', strike=150.0, right='P', multiplier='100', currency='USD', localSymbol='AAPL  241018P00150000', tradingClass='AAPL'), position=4.0, avgCost=182.19685)
# 2024-05-23 14:41:17,164 ib_async.wrapper INFO position: Position(account='U10394496', contract=Option(conId=657576926, symbol='QQQ', lastTradeDateOrContractMonth='20240930', strike=376.78, right='P', multiplier='100', currency='USD', localSymbol='QQQ   240930P00376780', tradingClass='QQQ'), position=1.0, avgCost=501.0369)
# 2024-05-23 14:41:17,166 ib_async.wrapper INFO position: Position(account='U10394496', contract=Option(conId=669333316, symbol='NVDA', lastTradeDateOrContractMonth='20240719', strike=555.0, right='P', multiplier='100', currency='USD', localSymbol='NVDA  240719P00555000', tradingClass='NVDA'), position=2.0, avgCost=349.4231)
# 2024-05-23 14:41:17,169 ib_async.wrapper INFO position: Position(account='U10394496', contract=Option(conId=613471094, symbol='GOOGL', lastTradeDateOrContractMonth='20240920', strike=120.0, right='P', multiplier='100', currency='USD', localSymbol='GOOGL 240920P00120000', tradingClass='GOOGL'), position=10.0, avgCost=51.44685)
# 2024-05-23 14:41:17,176 ib_async.wrapper INFO position: Position(account='U10394496', contract=Option(conId=699061747, symbol='NVDA', lastTradeDateOrContractMonth='20240719', strike=855.0, right='P', multiplier='100', currency='USD', localSymbol='NVDA  240719P00855000', tradingClass='NVDA'), position=1.0, avgCost=593.04685)
# 2024-05-23 14:41:17,182 ib_async.wrapper INFO position: Position(account='U10394496', contract=Option(conId=699536227, symbol='PINS', lastTradeDateOrContractMonth='20240607', strike=33.0, right='P', multiplier='100', currency='USD', localSymbol='PINS  240607P00033000', tradingClass='PINS'), position=40.0, avgCost=13.44685)
# 2024-05-23 14:41:17,189 ib_async.wrapper INFO position: Position(account='U10394496', contract=Future(conId=620730920, symbol='NQ', lastTradeDateOrContractMonth='20240621', multiplier='20', currency='USD', localSymbol='NQM4', tradingClass='NQ'), position=3.0, avgCost=373047.9010209)
# 2024-05-23 14:41:17,197 ib_async.wrapper INFO position: Position(account='U2340948', contract=Stock(conId=47486780, symbol='EDV', exchange='ARCA', currency='USD', localSymbol='EDV', tradingClass='EDV'), position=650.0, avgCost=77.7080769)
# 2024-05-23 14:41:17,203 ib_async.wrapper INFO position: Position(account='U10394496', contract=Option(conId=642744523, symbol='NVDA', lastTradeDateOrContractMonth='20240920', strike=510.0, right='P', multiplier='100', currency='USD', localSymbol='NVDA  240920P00510000', tradingClass='NVDA'), position=1.0, avgCost=501.0369)
# 2024-05-23 14:41:17,207 ib_async.wrapper INFO position: Position(account='U10394496', contract=Option(conId=699532596, symbol='QQQ', lastTradeDateOrContractMonth='20240607', strike=400.0, right='P', multiplier='100', currency='USD', localSymbol='QQQ   240607P00400000', tradingClass='QQQ'), position=2.0, avgCost=207.69685)
# 2024-05-23 14:41:17,210 ib_async.wrapper INFO position: Position(account='U10394496', contract=Option(conId=682677111, symbol='AMZN', lastTradeDateOrContractMonth='20241018', strike=130.0, right='P', multiplier='100', currency='USD', localSymbol='AMZN  241018P00130000', tradingClass='AMZN'), position=4.0, avgCost=115.68685)
# 2024-05-23 14:41:17,221 ib_async.wrapper INFO position: Position(account='U2340948', contract=Stock(conId=229726228, symbol='RSX', exchange='VALUE', currency='USD', localSymbol='RSX', tradingClass='RSX'), position=100.0, avgCost=6.889977)
# 2024-05-23 14:41:17,630 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.664e8040.01.01', time=datetime.datetime(2024, 5, 23, 10, 58, 57, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='SLD', shares=1.0, price=18970.5, permId=1394515163, clientId=1, orderId=285, liquidation=0, cumQty=1.0, avgPrice=18970.5, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-23 14:41:17,633 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.664e852d.01.01', time=datetime.datetime(2024, 5, 23, 12, 29, 56, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='BOT', shares=1.0, price=19002.75, permId=196158470, clientId=69, orderId=187, liquidation=0, cumQty=1.0, avgPrice=19002.75, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-23 14:41:17,642 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.664e8581.01.01', time=datetime.datetime(2024, 5, 23, 12, 30, 52, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='SLD', shares=1.0, price=19005.25, permId=196158471, clientId=69, orderId=188, liquidation=0, cumQty=1.0, avgPrice=19005.25, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-23 14:41:17,644 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.664e8687.01.01', time=datetime.datetime(2024, 5, 23, 12, 35, 59, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='BOT', shares=1.0, price=19014.25, permId=196158474, clientId=69, orderId=191, liquidation=0, cumQty=1.0, avgPrice=19014.25, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-23 14:41:17,648 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.664e8746.01.01', time=datetime.datetime(2024, 5, 23, 12, 42, 9, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='SLD', shares=1.0, price
tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='SLD', shares=1.0, price=18830.5, permId=1735428987, clientId=54, orderId=288, liquidation=0, cumQty=1.0, avgPrice=18830.5, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-23 14:41:17,934 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.664f082c.01.01', time=datetime.datetime(2024, 5, 23, 17, 33, 30, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='BOT', shares=1.0, price=18828.0, permId=1735428988, clientId=54, orderId=289, liquidation=0, cumQty=1.0, avgPrice=18828.0, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-23 14:41:17,935 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.664f08aa.01.01', time=datetime.datetime(2024, 5, 23, 17, 35, 36, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='SLD', shares=1.0, price=18831.75, permId=1735428990, clientId=54, orderId=291, liquidation=0, cumQty=1.0, avgPrice=18831.75, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-23 14:41:17,937 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.664f08b0.01.01', time=datetime.datetime(2024, 5, 23, 17, 35, 46, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='BOT', shares=1.0, price=18829.25, permId=1735428991, clientId=54, orderId=292, liquidation=0, cumQty=1.0, avgPrice=18829.25, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# 2024-05-23 14:41:17,938 ib_async.wrapper INFO execDetails Execution(execId='0000d94c.664f097c.01.01', time=datetime.datetime(2024, 5, 23, 17, 36, 50, tzinfo=datetime.timezone.utc), acctNumber='U10394496', exchange='CME', side='SLD', shares=1.0, price=18817.25, permId=1735428992, clientId=54, orderId=293, liquidation=0, cumQty=1.0, avgPrice=18817.25, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=1, pendingPriceRevision=False)
# ...
# 2024-05-23 14:41:19,314 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f0e77.01.01', commission=2.0, currency='USD', realizedPNL=46.0, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 14:41:19,316 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f0ef6.01.01', commission=2.0, currency='USD', realizedPNL=0.0, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 14:41:19,317 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f0fa5.01.01', commission=2.0, currency='USD', realizedPNL=-89.0, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 14:41:19,318 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f0fb7.01.01', commission=2.0, currency='USD', realizedPNL=0.0, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 14:41:19,320 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f1031.01.01', commission=2.0, currency='USD', realizedPNL=0.0, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 14:41:19,321 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f104e.01.01', commission=2.0, currency='USD', realizedPNL=26.0, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 14:41:19,322 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f10dd.01.01', commission=2.0, currency='USD', realizedPNL=0.0, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 14:41:19,323 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f10ed.01.01', commission=2.0, currency='USD', realizedPNL=36.0, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 14:41:19,324 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f1182.01.01', commission=2.0, currency='USD', realizedPNL=0.0, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 14:41:19,326 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f11cc.01.01', commission=2.0, currency='USD', realizedPNL=118.5, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 14:41:19,327 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f1202.01.01', commission=2.0, currency='USD', realizedPNL=0.0, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 14:41:19,328 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f128e.01.01', commission=2.0, currency='USD', realizedPNL=104.75, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 14:41:19,331 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f12c9.01.01', commission=2.0, currency='USD', realizedPNL=0.0, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 14:41:19,333 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f1f86.01.01', commission=2.0, currency='USD', realizedPNL=0.0, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 14:41:19,335 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f1f96.01.01', commission=2.0, currency='USD', realizedPNL=-746.083333, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 14:41:19,337 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f1ffa.01.01', commission=2.0, currency='USD', realizedPNL=0.0, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 14:41:19,338 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f2083.01.01', commission=2.0, currency='USD', realizedPNL=-467.055556, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 14:41:19,339 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f2111.01.01', commission=2.0, currency='USD', realizedPNL=0.0, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 14:41:19,341 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f211e.01.01', commission=2.0, currency='USD', realizedPNL=-304.37037, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 14:41:19,342 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f213f.01.01', commission=2.0, currency='USD', realizedPNL=0.0, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 14:41:19,344 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f2265.01.01', commission=2.0, currency='USD', realizedPNL=-222.580247, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 14:41:19,348 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f22b7.01.01', commission=2.0, currency='USD', realizedPNL=0.0, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 14:41:19,349 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f22d1.01.01', commission=2.0, currency='USD', realizedPNL=-74.720165, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 14:41:19,350 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f23cc.01.01', commission=2.0, currency='USD', realizedPNL=0.0, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 14:41:19,352 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f23e4.01.01', commission=2.0, currency='USD', realizedPNL=160.51989, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 14:41:19,353 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f244e.01.01', commission=2.0, currency='USD', realizedPNL=0.0, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 14:41:19,355 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f2453.01.01', commission=2.0, currency='USD', realizedPNL=0.679927, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 14:41:19,356 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f2486.01.01', commission=2.0, currency='USD', realizedPNL=0.0, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 14:41:19,357 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f248d.01.01', commission=2.0, currency='USD', realizedPNL=-22.546715, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 14:41:19,358 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f24a9.01.01', commission=2.0, currency='USD', realizedPNL=0.0, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 14:41:19,360 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f3237.01.01', commission=2.0, currency='USD', realizedPNL=0.0, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 14:41:19,362 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f3430.01.01', commission=2.0, currency='USD', realizedPNL=-1062.023358, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 14:41:19,363 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f3495.01.01', commission=2.0, currency='USD', realizedPNL=0.0, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 14:41:19,364 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f3524.01.01', commission=2.0, currency='USD', realizedPNL=-728.767518, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 14:41:19,369 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f3547.01.01', commission=2.0, currency='USD', realizedPNL=0.0, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 14:41:19,371 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f3676.01.01', commission=2.0, currency='USD', realizedPNL=-553.825639, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 14:41:19,372 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f3911.01.01', commission=2.0, currency='USD', realizedPNL=0.0, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 14:41:19,374 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f3a61.01.01', commission=2.0, currency='USD', realizedPNL=-372.619229, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 14:41:19,378 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f3a72.01.01', commission=2.0, currency='USD', realizedPNL=0.0, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 14:41:19,380 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f3acb.01.01', commission=2.0, currency='USD', realizedPNL=-56.714422, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 14:41:19,382 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f3ae2.01.01', commission=2.0, currency='USD', realizedPNL=0.0, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 14:41:19,385 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f3b69.01.01', commission=2.0, currency='USD', realizedPNL=-259.785816, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 14:41:19,386 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f3b74.01.01', commission=2.0, currency='USD', realizedPNL=0.0, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 14:41:19,388 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f3be5.01.01', commission=2.0, currency='USD', realizedPNL=-132.089362, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 14:41:19,389 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f3bea.01.01', commission=2.0, currency='USD', realizedPNL=0.0, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 14:41:19,390 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f3c14.01.01', commission=2.0, currency='USD', realizedPNL=-156.317022, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 14:41:19,391 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f3c99.01.01', commission=2.0, currency='USD', realizedPNL=0.0, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 14:41:19,392 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f3ce6.01.01', commission=2.0, currency='USD', realizedPNL=75.512234, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 14:41:19,393 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f3f0c.01.01', commission=2.0, currency='USD', realizedPNL=0.0, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 14:41:19,395 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f3f77.01.01', commission=2.0, currency='USD', realizedPNL=219.384175, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 14:41:19,395 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f3f85.01.01', commission=2.0, currency='USD', realizedPNL=0.0, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 14:41:19,396 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f3fe8.01.01', commission=2.0, currency='USD', realizedPNL=197.288131, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 14:41:19,397 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f3ff4.01.01', commission=2.0, currency='USD', realizedPNL=0.0, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 14:41:19,399 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f4084.01.01', commission=2.0, currency='USD', realizedPNL=100.716099, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 14:41:19,401 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f408a.01.01', commission=2.0, currency='USD', realizedPNL=0.0, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 14:41:19,403 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f40da.01.01', commission=2.0, currency='USD', realizedPNL=198.287074, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 14:41:19,404 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f4109.01.01', commission=2.0, currency='USD', realizedPNL=0.0, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 14:41:19,405 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f420e.01.01', commission=2.0, currency='USD', realizedPNL=496.465305, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 14:41:19,407 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f4243.01.01', commission=2.0, currency='USD', realizedPNL=0.0, yield_=0.0, yieldRedemptionDate=0)
# 2024-05-23 14:41:19,408 ib_async.wrapper INFO commissionReport: CommissionReport(execId='0000d94c.664f42c5.01.01', commission=2.0, currency='USD', realizedPNL=430.098979, yield_=0.0, yieldRedemptionDate=0)
# NQ Order Book::
#      3.0    18690.5 | 18691.0    6.0
#      6.0   18690.25 | 18691.25   6.0
#      5.0    18690.0 | 18691.5    9.0
#      6.0   18689.75 | 18691.75   9.0
#      7.0    18689.5 | 18692.0    7.0
#
# Intraday Executions: 158
#
# POSITIONS::
# BA 254.0 @ 10.1605561025
# EDV 650.0 @ 3.885403845
# RSX 100.0 @ 0.34449885
# HYG 50.0 @ 0.6223425
# AAPL 4.0 @ 9.109842500000001
# QQQ 1.0 @ 25.051845
# NVDA 2.0 @ 17.471155
# GOOGL 10.0 @ 2.5723425
# NVDA 1.0 @ 29.652342499999996
# PINS 40.0 @ 0.6723425
# NQ 3.0 @ 18652.395051045
# NVDA 1.0 @ 25.051845
# QQQ 2.0 @ 10.384842500000001
# AMZN 4.0 @ 5.7843425
#
# ACCOUNT SUMMARY::
#
# AccountType : INDIVIDUAL
# Cushion : 0.536769
# LookAheadNextChange : 1716494400
# AccruedCash : 7.70
# AvailableFunds : 47781.78
# BuyingPower : 215315.41
# EquityWithLoanValue : 53828.85
# ExcessLiquidity : 53828.85
# FullAvailableFunds : 28647.18
# FullExcessLiquidity : 34942.60
# FullInitMarginReq : 69249.61
# FullMaintMarginReq : 62954.19
# GrossPositionValue : 2378.55
# InitMarginReq : 48474.72
# LookAheadAvailableFunds : 28647.18
# LookAheadExcessLiquidity : 34942.60
# LookAheadInitMarginReq : 69249.61
# LookAheadMaintMarginReq : 62954.19
# MaintMarginReq : 44067.93
# NetLiquidation : 100283.03
# PreviousDayEquityWithLoanValue : 0.00
# RegTEquity : 7.70
# RegTMargin : 0.00
# SMA : 622874.16
# TotalCashValue : 97896.78
#
# :: trades ::
#    orderId  clientId      permId action  totalQuantity orderType  lmtPrice  \
# 0      311        54  1735429010   SELL            1.0       LMT  18766.75
# 1      378         6  1735430610    BUY            1.0       LMT  18670.25
# 2      379         6  1735430611    BUY            1.0       LMT  18670.25
# 3        0         0  2099801404    BUY            1.0       LMT  18040.50
# 4      334        54  1735429255   SELL            1.0       LMT  18706.50
# 5      271        69   196158554   SELL            1.0       LMT  18924.50
# 6      196        69   196158479   SELL            1.0       LMT  19021.75
#
#    auxPrice  tif activeStartTime  ... usePriceMgmtAlgo    duration  \
# 0       0.0  GTC                  ...            False  2147483647
# 1       0.0  GTC                  ...            False  2147483647
# 2       0.0  GTC                  ...            False  2147483647
# 3       0.0  GTC                  ...            False  2147483647
# 4       0.0  GTC                  ...            False  2147483647
# 5       0.0  GTC                  ...            False  2147483647
# 6       0.0  GTC                  ...            False  2147483647
#
#     postToAts advancedErrorOverride  manualOrderTime  minTradeQty  \
# 0  2147483647                                          2147483647
# 1  2147483647                                          2147483647
# 2  2147483647                                          2147483647
# 3  2147483647                                          2147483647
# 4  2147483647                                          2147483647
# 5  2147483647                                          2147483647
# 6  2147483647                                          2147483647
#
#    minCompeteSize  competeAgainstBestOffset  midOffsetAtWhole  midOffsetAtHalf
# 0      2147483647             1.797693e+308     1.797693e+308    1.797693e+308
# 1      2147483647             1.797693e+308     1.797693e+308    1.797693e+308
# 2      2147483647             1.797693e+308     1.797693e+308    1.797693e+308
# 3      2147483647             1.797693e+308     1.797693e+308    1.797693e+308
# 4      2147483647             1.797693e+308     1.797693e+308    1.797693e+308
# 5      2147483647             1.797693e+308     1.797693e+308    1.797693e+308
# 6      2147483647             1.797693e+308     1.797693e+308    1.797693e+308
#
# [7 rows x 139 columns]

# %%
def parse_ibrecords(data_array):

    data_list = []

    for obj in data_array:
        data = {}

        if hasattr(obj, "contract"):
            util.logging.debug(obj.contract)
            contract = util.dataclassNonDefaults(obj.contract)
            data = {**data, **contract}

        if hasattr(obj, "order"):
            util.logging.debug(obj.order)
            order = util.dataclassNonDefaults(obj.order)
            order.pop("softDollarTier")
            data = {**data, **order}

        if hasattr(obj, "orderStatus"):
            util.logging.debug(obj.orderStatus)
            orderStatus = util.dataclassNonDefaults(obj.orderStatus)
            data = {**data, **orderStatus}

        if hasattr(obj, "fills"):
            util.logging.debug(obj.fills)
            fills = {"fills": obj.fills}
            data = {**data, **fills}

        if hasattr(obj, "log"):
            util.logging.debug(obj.log)
            logs = {"log": [util.dataclassAsDict(e) for e in obj.log]}
            data = {**data, **logs}

        if hasattr(obj, "advancedError"):
            util.logging.debug(obj.advancedError)
            advancedError = {"advancedError": obj.advancedError}
            data = {**data, **advancedError}

        if type(obj) == Order:
            util.logging.debug(obj)
            order = util.dataclassNonDefaults(obj)
            order.pop("softDollarTier")
            data = {**data, **order}

        data_list.append(data)

    return data_list


def print_ibrecords_table(
    data_array,
    cols=[
        "localSymbol",
        "permId",
        "status",
        "orderType",
        "action",
        "lmtPrice",
        "remaining",
    ],
):
    df = pd.DataFrame(data_array)
    df = df[cols]
    print(df)


# # openTrades = parse_ibrecords(ib.openTrades())
accountSummary = ib.accountSummary()
accountValues = ib.accountValues()

# openTrades = parse_ibrecords(ib.openTrades())
# util.df([d for d in openTrades])

openOrders = parse_ibrecords(ib.openOrders())
util.df([d for d in openOrders])

# trades = parse_ibrecords(ib.trades())
# util.df([d for d in trades])

# orders = parse_ibrecords(ib.orders())
# util.df([d for d in orders])
# Out:
#    orderId  clientId      permId action  totalQuantity orderType  lmtPrice  \
# 0    311.0      54.0  1735429010   SELL            1.0       LMT  18766.75
# 1    378.0       6.0  1735430610    BUY            1.0       LMT  18670.25
# 2    379.0       6.0  1735430611    BUY            1.0       LMT  18670.25
# 3      NaN       NaN  2099801404    BUY            1.0       LMT  18040.50
# 4    334.0      54.0  1735429255   SELL            1.0       LMT  18706.50
# 5    271.0      69.0   196158554   SELL            1.0       LMT  18924.50
# 6    196.0      69.0   196158479   SELL            1.0       LMT  19021.75
#
#    auxPrice  tif  ocaType  ...  openClose volatilityType  \
# 0       0.0  GTC        3  ...                         0
# 1       0.0  GTC        3  ...                         0
# 2       0.0  GTC        3  ...                         0
# 3       0.0  GTC        3  ...                         0
# 4       0.0  GTC        3  ...                         0
# 5       0.0  GTC        3  ...                         0
# 6       0.0  GTC        3  ...                         0
#
#   deltaNeutralOrderType  referencePriceType    account  clearingIntent  \
# 0                  None                   0  U10394496              IB
# 1                  None                   0  U10394496              IB
# 2                  None                   0  U10394496              IB
# 3                  None                   0  U10394496              IB
# 4                  None                   0  U10394496              IB
# 5                  None                   0  U10394496              IB
# 6                  None                   0  U10394496              IB
#
#   adjustedOrderType cashQty dontUseAutoPriceForHedge    ocaGroup
# 0              None     0.0                     True         NaN
# 1              None     0.0                     True         NaN
# 2              None     0.0                     True         NaN
# 3              None     0.0                     True  2099801403
# 4              None     0.0                     True         NaN
# 5              None     0.0                     True         NaN
# 6              None     0.0                     True         NaN
#
# [7 rows x 22 columns]

# %%
def print_openTrades():
    print(":: openTrades ::")
    util.df([t.order for t in ib.openTrades()]).sort_values("permId").loc[
        :,
        [
            "orderId",
            "clientId",
            "permId",
            "action",
            "totalQuantity",
            "orderType",
            "lmtPrice",
            "auxPrice",
            "tif",
        ],
    ]


print_openTrades()
# Out:
# :: openTrades ::

# %%
util.df(ib.positions()).sort_values("account", ascending=False)
# Out:
#       account                                           contract  position  \
# 0    U2340948  Stock(conId=4762, symbol='BA', exchange='NYSE'...     254.0
# 1    U2340948  Stock(conId=47486780, symbol='EDV', exchange='...     650.0
# 2    U2340948  Stock(conId=229726228, symbol='RSX', exchange=...     100.0
# 3   U10394496  Option(conId=637079300, symbol='HYG', lastTrad...      50.0
# 4   U10394496  Option(conId=682674010, symbol='AAPL', lastTra...       4.0
# 5   U10394496  Option(conId=657576926, symbol='QQQ', lastTrad...       1.0
# 6   U10394496  Option(conId=669333316, symbol='NVDA', lastTra...       2.0
# 7   U10394496  Option(conId=613471094, symbol='GOOGL', lastTr...      10.0
# 8   U10394496  Option(conId=699061747, symbol='NVDA', lastTra...       1.0
# 9   U10394496  Option(conId=699536227, symbol='PINS', lastTra...      40.0
# 10  U10394496  Future(conId=620730920, symbol='NQ', lastTrade...       3.0
# 11  U10394496  Option(conId=642744523, symbol='NVDA', lastTra...       1.0
# 12  U10394496  Option(conId=699532596, symbol='QQQ', lastTrad...       2.0
# 13  U10394496  Option(conId=682677111, symbol='AMZN', lastTra...       4.0
#
#           avgCost
# 0      203.211122
# 1       77.708077
# 2        6.889977
# 3       12.446850
# 4      182.196850
# 5      501.036900
# 6      349.423100
# 7       51.446850
# 8      593.046850
# 9       13.446850
# 10  373047.901021
# 11     501.036900
# 12     207.696850
# 13     115.686850

# %%
def run_strategy(strategy_details, open_permId, close_permId, cancel_permids=[]):
    open_trade = None
    close_trade = None
    open_order = None
    close_order = None
    open_order_ts = None

    push_notifications(
        f"-------- {strategy_details} / {open_permId} / {close_permId} / {cancel_permids}"
    )

    if open_permId is not None:
        orders = [t.order for t in ib.reqAllOpenOrders()]
        for o in orders:
            if o.permId == open_permId:
                open_order = o

    if open_order is not None:
        push_notifications(f"OPEN ORDER:: {open_order}")

    if open_trade is None:
        trades = ib.trades()
        for o in trades:
            if o.orderStatus.permId == open_permId:
                open_trade = o

    # push_msg(f"OPEN TRADE:: {open_trade.order}")

    if close_permId is not None:
        for o in orders:
            if o.permId == close_permId:
                close_order = o

    if close_order is not None:
        push_notifications(f"CLOSE ORDER:: {close_order}")

    if close_trade is None:
        trades = ib.trades()
        for o in trades:
            if o.orderStatus.permId == close_permId:
                close_trade = o

    # print(f"CLOSE TRADE:: {close_trade}")

    for permId in cancel_permids:
        cancelled_order = None
        for o in orders:
            if o.permId == permId:
                print("Cancelling order.permId {o.permId}")
                cancelled_order = ib.cancelOrder(o)
                ib.sleep(2)
                if cancelled_order.orderStatus.status == "Cancelled":
                    print(f"Order {o.permId} has been cancelled")
                else:
                    raise Exception("Unable to cancel order {o.permId}")

        if cancelled_order is None:
            raise Exception(":: ORDER TO CANCEL NOT FOUND ::  {permId}")

    pause = False
    ib.sleep(5)

    while True:
        clear_output(wait=True)

        # first order of the strategy
        if open_trade is None and close_trade is None:
            action = strategy_details["open_action"]
            qty = strategy_details["open_qty"]

            if strategy_details["open_ref"] == "bid":
                price_ref = ticker.domBids[0].price
            elif strategy_details["open_ref"] == "ask":
                price_ref = ticker.domAsks[0].price
            elif strategy_details["open_ref"] == "mid":
                price_ref = (ticker.domAsks[0].price + ticker.domBids[0].price) / 2
            elif strategy_details["open_ref"] == "last":
                raise Exception("Not implemented")

            lmtPrice = (
                price_ref
                + strategy_details["open_ticks"] * strategy_details["tick_increment"]
            )
            print(
                f"Placing open trade: {action}, {strategy_details['open_type']}, totalQuantity {qty}, lmtPrice {lmtPrice}\n"
            )

            if strategy_details["open_type"] == "LIMIT":
                open_order = LimitOrder(
                    action=action,
                    totalQuantity=qty,
                    lmtPrice=lmtPrice,
                    account="U10394496",
                )
            else:
                raise Exception("Not implemented")

            open_trade = ib.placeOrder(contract, open_order)
            trade = open_trade

            push_notifications(
                f"OPEN ORDER PLACED :: #{trade.order.permId} {trade.orderStatus.status} {trade.contract.symbol} {trade.order.action} {trade.orderStatus.filled}/{trade.orderStatus.remaining} @ {trade.order.lmtPrice}"
            )

            open_order_ts = datetime.datetime.now()

        print("OPEN ORDER::")
        print_order(open_trade)
        print()

        if open_trade is not None:
            if open_trade.orderStatus.status == "Submitted" and close_trade is None:
                print(
                    f"Waiting to get filled on order #{open_trade.order.permId} ({open_trade.orderStatus.status})\n"
                )

                if (
                    open_order_ts is None
                    or datetime.datetime.now() - open_order_ts
                    > datetime.timedelta(seconds=strategy_details["pause_seconds"])
                ):
                    print("Cancelling order due to timeout:")
                    ib.cancelOrder(open_trade.order)
                    print()

            if open_trade.orderStatus.status == "Filled" and close_trade is None:
                print(
                    "Filled on open_trade {open_trade.orderStatus.status} {open_trade.orderStatus.avgFillPrice} {open_trade.orderStatus.status}"
                )

                action = strategy_details["close_action"]
                qty = strategy_details["close_qty"]

                if strategy_details["close_ref"] == "open_price_fill":
                    price_ref = open_trade.orderStatus.avgFillPrice
                if strategy_details["close_ref"] == "bid":
                    price_ref = ticker.domBids[0].price
                elif strategy_details["close_ref"] == "ask":
                    price_ref = ticker.domAsks[0].price
                elif strategy_details["close_ref"] == "mid":
                    price_ref = (ticker.domAsks[0].price + ticker.domBids[0].price) / 2
                elif strategy_details["close_ref"] == "last":
                    raise Exception("Not implemented")

                lmtPrice = (
                    price_ref
                    + strategy_details["close_ticks"]
                    * strategy_details["tick_increment"]
                )

                if strategy_details["close_type"] == "LIMIT":
                    close_order = LimitOrder(
                        action=action,
                        totalQuantity=qty,
                        lmtPrice=lmtPrice,
                        account="U10394496",
                    )
                else:
                    raise Exception("Not implemented")

                close_trade = ib.placeOrder(contract, close_order)

                # chime.info()
                push_notifications(msg=f"OPEN ORDER FILLED:: {open_trade.order}")
                push_notifications(msg=f"CLOSE ORDER PLACED:: {close_trade.order}")

            elif (
                open_trade.orderStatus.status == "Inactive"
                or open_trade.orderStatus.status == "Cancelled"
            ) and close_trade is None:
                # push_notifications(f"OPEN TRADE CANCELLED:: {open_trade.order}")
                open_trade = None

        print(f"CLOSE ORDER::")
        print_order(close_trade)
        print()

        if close_trade is not None:
            if close_trade.orderStatus.status == "Filled":
                print(
                    "Close trade filled @ {}\n".format(
                        close_trade.orderStatus.avgFillPrice
                    )
                )
                os.system("say beep")
                chime_success()
                push_notifications(f"CLOSE TRADE FILLED:: {close_trade.order}")
                print()
                open_trade = None
                close_trade = None

                pause = True

        ib.accountSummary()

        print_orderbook()
        print()
        print("POSITIONS::")
        future = [pos for pos in ib.positions() if pos.contract.secType == "FUT"]
        for f in future:
            print(
                f"{f.contract.symbol} {f.position} @ {f.avgCost/float(contract.multiplier)}"
            )
        print()

        print(
            util.df(ib.openOrders())
            .sort_values("lmtPrice", ascending=False)
            .loc[
                :,
                [
                    "orderId",
                    "permId",
                    "action",
                    "totalQuantity",
                    "orderType",
                    "lmtPrice",
                    "tif",
                ],
            ]
        )

        # openOrders = parse_ibrecords(ib.openOrders())
        # print_ibrecords_table(
        #     openOrders,
        #     cols=[
        #         "localSymbol",
        #         "permId",
        #         "status",
        #         "orderType",
        #         "action",
        #         "lmtPrice",
        #         "remaining",
        #     ],
        # )

        if pause:
            ib.sleep(strategy_details["pause_seconds"])
            pause = False
        else:
            ib.sleep(1)


sell_scalp = {
    "strategy": "SELL TO OPEN SCALP",
    "contract": "NQM2024",
    "tick_increment": 0.25,
    "open_qty": 1,
    "open_type": "LIMIT",
    "open_action": "SELL",
    "open_ref": "ask",
    "open_ticks": 10,
    "close_qty": 1,
    "close_type": "LIMIT",
    "close_action": "BUY",
    "close_ref": "open_price_fill",
    "close_ticks": -15,
    "pause_seconds": 40,
}

buy_scalp = {
    "strategy": "BUY TO OPEN SCALP",
    "contract": "NQM2024",
    "tick_increment": 0.25,
    "open_qty": 1,
    "open_type": "LIMIT",
    "open_action": "BUY",
    "open_ref": "bid",
    "open_ticks": -10,
    "close_qty": 1,
    "close_type": "LIMIT",
    "close_action": "SELL",
    "close_ref": "open_price_fill",
    "close_ticks": 15,
    "pause_seconds": 55,
}


run_strategy(
    strategy_details=sell_scalp,
    open_permId=1735431829,
    close_permId=None,
    cancel_permids=[],
)
# Out:
# OPEN ORDER::
# symbol	permId		status		action	filled	remaining	lmtPrice
# NQ	1735431830	Submitted	SELL	0.0	1.0		18688.25
#
# Waiting to get filled on order #1735431830 (Submitted)
#
# CLOSE ORDER::
#
#
# NQ Order Book::
#     11.0   18685.25 | 18686.0    12.0
#      7.0    18685.0 | 18686.25   2.0
#      3.0   18684.75 | 18686.5    4.0
#     11.0    18684.5 | 18686.75   4.0
#      6.0   18684.25 | 18687.0    4.0
#
#
# POSITIONS::
# NQ 2.0 @ 18684.5445083375
#
#    orderId      permId action  totalQuantity orderType  lmtPrice  tif
# 6      196   196158479   SELL            1.0       LMT  19021.75  GTC
# 5      271   196158554   SELL            1.0       LMT  18924.50  GTC
# 0      311  1735429010   SELL            1.0       LMT  18766.75  GTC
# 4      334  1735429255   SELL            1.0       LMT  18706.50  GTC
# 7      427  1735431830   SELL            1.0       LMT  18688.25
# 1      378  1735430610    BUY            1.0       LMT  18670.25  GTC
# 2      379  1735430611    BUY            1.0       LMT  18670.25  GTC
# 3        0  2099801404    BUY            1.0       LMT  18040.50  GTC
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[27], line 279
#     244 sell_scalp = {
#     245     "strategy": "SELL TO OPEN SCALP",
#     246     "contract": "NQM2024",
#    (...)
#     258     "pause_seconds": 40,
#     259 }
#     261 buy_scalp = {
#     262     "strategy": "BUY TO OPEN SCALP",
#     263     "contract": "NQM2024",
#    (...)
#     275     "pause_seconds": 55,
#     276 }
# --> 279 run_strategy(
#     280     strategy_details=sell_scalp,
#     281     open_permId=1735431829,
#     282     close_permId=None,
#     283     cancel_permids=[],
#     284 )
#
# Cell In[27], line 241, in run_strategy(strategy_details, open_permId, close_permId, cancel_permids)
#     239     pause = False
#     240 else:
# --> 241     ib.sleep(1)
#
# File ~/ib_async/.venv/lib/python3.12/site-packages/ib_async/util.py:402, in sleep(secs)
#     394 def sleep(secs: float = 0.02) -> bool:
#     395     """
#     396     Wait for the given amount of seconds while everything still keeps
#     397     processing in the background. Never use time.sleep().
#    (...)
#     400         secs (float): Time in seconds to wait.
#     401     """
# --> 402     run(asyncio.sleep(secs))
#     403     return True
#
# File ~/ib_async/.venv/lib/python3.12/site-packages/ib_async/util.py:357, in run(timeout, *awaitables)
#     355 globalErrorEvent.connect(onError)
#     356 try:
# --> 357     result = loop.run_until_complete(task)
#     358 except asyncio.CancelledError as e:
#     359     raise globalErrorEvent.value() or e
#
# File ~/ib_async/.venv/lib/python3.12/site-packages/nest_asyncio.py:92, in _patch_loop.<locals>.run_until_complete(self, future)
#      90     f._log_destroy_pending = False
#      91 while not f.done():
# ---> 92     self._run_once()
#      93     if self._stopping:
#      94         break
#
# File ~/ib_async/.venv/lib/python3.12/site-packages/nest_asyncio.py:115, in _patch_loop.<locals>._run_once(self)
#     108     heappop(scheduled)
#     110 timeout = (
#     111     0 if ready or self._stopping
#     112     else min(max(
#     113         scheduled[0]._when - self.time(), 0), 86400) if scheduled
#     114     else None)
# --> 115 event_list = self._selector.select(timeout)
#     116 self._process_events(event_list)
#     118 end_time = self.time() + self._clock_resolution
#
# File /usr/lib/python3.12/selectors.py:468, in EpollSelector.select(self, timeout)
#     466 ready = []
#     467 try:
# --> 468     fd_event_list = self._selector.poll(timeout, max_ev)
#     469 except InterruptedError:
#     470     return ready
#
# KeyboardInterrupt:

# %%
# Out:
# [{'secType': 'FUT',
#   'conId': 620730920,
#   'symbol': 'NQ',
#   'lastTradeDateOrContractMonth': '20240621',
#   'right': '?',
#   'multiplier': '20',
#   'exchange': 'CME',
#   'currency': 'USD',
#   'localSymbol': 'NQM4',
#   'tradingClass': 'NQ',
#   'orderId': 311,
#   'clientId': 54,
#   'permId': 1735429010,
#   'action': 'SELL',
#   'totalQuantity': 1.0,
#   'orderType': 'LMT',
#   'lmtPrice': 18766.75,
#   'auxPrice': 0.0,
#   'tif': 'GTC',
#   'ocaType': 3,
#   'displaySize': 2147483647,
#   'rule80A': '0',
#   'openClose': '',
#   'volatilityType': 0,
#   'deltaNeutralOrderType': 'None',
#   'referencePriceType': 0,
#   'account': 'U10394496',
#   'clearingIntent': 'IB',
#   'adjustedOrderType': 'None',
#   'cashQty': 0.0,
#   'dontUseAutoPriceForHedge': True,
#   'status': 'Submitted',
#   'remaining': 1.0,
#   'fills': [],
#   'log': [{'time': datetime.datetime(2024, 5, 23, 19, 41, 18, 677537, tzinfo=datetime.timezone.utc),
#     'status': 'Submitted',
#     'message': '',
#     'errorCode': 0}],
#   'advancedError': ''},
#  {'secType': 'FUT',
#   'conId': 620730920,
#   'symbol': 'NQ',
#   'lastTradeDateOrContractMonth': '20240621',
#   'right': '?',
#   'multiplier': '20',
#   'exchange': 'CME',
#   'currency': 'USD',
#   'localSymbol': 'NQM4',
#   'tradingClass': 'NQ',
#   'orderId': 378,
#   'clientId': 6,
#   'permId': 1735430610,
#   'action': 'BUY',
#   'totalQuantity': 1.0,
#   'orderType': 'LMT',
#   'lmtPrice': 18670.25,
#   'auxPrice': 0.0,
#   'tif': 'GTC',
#   'ocaType': 3,
#   'displaySize': 2147483647,
#   'rule80A': '0',
#   'openClose': '',
#   'volatilityType': 0,
#   'deltaNeutralOrderType': 'None',
#   'referencePriceType': 0,
#   'account': 'U10394496',
#   'clearingIntent': 'IB',
#   'adjustedOrderType': 'None',
#   'cashQty': 0.0,
#   'dontUseAutoPriceForHedge': True,
#   'status': 'Submitted',
#   'remaining': 1.0,
#   'fills': [],
#   'log': [{'time': datetime.datetime(2024, 5, 23, 19, 41, 18, 677537, tzinfo=datetime.timezone.utc),
#     'status': 'Submitted',
#     'message': '',
#     'errorCode': 0}],
#   'advancedError': ''},
#  {'secType': 'FUT',
#   'conId': 620730920,
#   'symbol': 'NQ',
#   'lastTradeDateOrContractMonth': '20240621',
#   'right': '?',
#   'multiplier': '20',
#   'exchange': 'CME',
#   'currency': 'USD',
#   'localSymbol': 'NQM4',
#   'tradingClass': 'NQ',
#   'orderId': 379,
#   'clientId': 6,
#   'permId': 1735430611,
#   'action': 'BUY',
#   'totalQuantity': 1.0,
#   'orderType': 'LMT',
#   'lmtPrice': 18670.25,
#   'auxPrice': 0.0,
#   'tif': 'GTC',
#   'ocaType': 3,
#   'displaySize': 2147483647,
#   'rule80A': '0',
#   'openClose': '',
#   'volatilityType': 0,
#   'deltaNeutralOrderType': 'None',
#   'referencePriceType': 0,
#   'account': 'U10394496',
#   'clearingIntent': 'IB',
#   'adjustedOrderType': 'None',
#   'cashQty': 0.0,
#   'dontUseAutoPriceForHedge': True,
#   'status': 'Submitted',
#   'remaining': 1.0,
#   'fills': [],
#   'log': [{'time': datetime.datetime(2024, 5, 23, 19, 41, 18, 677537, tzinfo=datetime.timezone.utc),
#     'status': 'Submitted',
#     'message': '',
#     'errorCode': 0}],
#   'advancedError': ''},
#  {'secType': 'FUT',
#   'conId': 620730920,
#   'symbol': 'NQ',
#   'lastTradeDateOrContractMonth': '20240621',
#   'right': '?',
#   'multiplier': '20',
#   'exchange': 'CME',
#   'currency': 'USD',
#   'localSymbol': 'NQM4',
#   'tradingClass': 'NQ',
#   'permId': 2099801404,
#   'action': 'BUY',
#   'totalQuantity': 1.0,
#   'orderType': 'LMT',
#   'lmtPrice': 18040.5,
#   'auxPrice': 0.0,
#   'tif': 'GTC',
#   'ocaGroup': '2099801403',
#   'ocaType': 3,
#   'displaySize': 2147483647,
#   'rule80A': '0',
#   'openClose': '',
#   'volatilityType': 0,
#   'deltaNeutralOrderType': 'None',
#   'referencePriceType': 0,
#   'account': 'U10394496',
#   'clearingIntent': 'IB',
#   'adjustedOrderType': 'None',
#   'cashQty': 0.0,
#   'dontUseAutoPriceForHedge': True,
#   'status': 'Submitted',
#   'remaining': 1.0,
#   'fills': [],
#   'log': [{'time': datetime.datetime(2024, 5, 23, 19, 41, 18, 677537, tzinfo=datetime.timezone.utc),
#     'status': 'Submitted',
#     'message': '',
#     'errorCode': 0}],
#   'advancedError': ''},
#  {'secType': 'FUT',
#   'conId': 620730920,
#   'symbol': 'NQ',
#   'lastTradeDateOrContractMonth': '20240621',
#   'right': '?',
#   'multiplier': '20',
#   'exchange': 'CME',
#   'currency': 'USD',
#   'localSymbol': 'NQM4',
#   'tradingClass': 'NQ',
#   'orderId': 334,
#   'clientId': 54,
#   'permId': 1735429255,
#   'action': 'SELL',
#   'totalQuantity': 1.0,
#   'orderType': 'LMT',
#   'lmtPrice': 18706.5,
#   'auxPrice': 0.0,
#   'tif': 'GTC',
#   'ocaType': 3,
#   'displaySize': 2147483647,
#   'rule80A': '0',
#   'openClose': '',
#   'volatilityType': 0,
#   'deltaNeutralOrderType': 'None',
#   'referencePriceType': 0,
#   'account': 'U10394496',
#   'clearingIntent': 'IB',
#   'adjustedOrderType': 'None',
#   'cashQty': 0.0,
#   'dontUseAutoPriceForHedge': True,
#   'status': 'Submitted',
#   'remaining': 1.0,
#   'fills': [],
#   'log': [{'time': datetime.datetime(2024, 5, 23, 19, 41, 18, 677537, tzinfo=datetime.timezone.utc),
#     'status': 'Submitted',
#     'message': '',
#     'errorCode': 0}],
#   'advancedError': ''},
#  {'secType': 'FUT',
#   'conId': 620730920,
#   'symbol': 'NQ',
#   'lastTradeDateOrContractMonth': '20240621',
#   'right': '?',
#   'multiplier': '20',
#   'exchange': 'CME',
#   'currency': 'USD',
#   'localSymbol': 'NQM4',
#   'tradingClass': 'NQ',
#   'orderId': 271,
#   'clientId': 69,
#   'permId': 196158554,
#   'action': 'SELL',
#   'totalQuantity': 1.0,
#   'orderType': 'LMT',
#   'lmtPrice': 18924.5,
#   'auxPrice': 0.0,
#   'tif': 'GTC',
#   'ocaType': 3,
#   'displaySize': 2147483647,
#   'rule80A': '0',
#   'openClose': '',
#   'volatilityType': 0,
#   'deltaNeutralOrderType': 'None',
#   'referencePriceType': 0,
#   'account': 'U10394496',
#   'clearingIntent': 'IB',
#   'adjustedOrderType': 'None',
#   'cashQty': 0.0,
#   'dontUseAutoPriceForHedge': True,
#   'status': 'Submitted',
#   'remaining': 1.0,
#   'fills': [],
#   'log': [{'time': datetime.datetime(2024, 5, 23, 19, 41, 18, 677537, tzinfo=datetime.timezone.utc),
#     'status': 'Submitted',
#     'message': '',
#     'errorCode': 0}],
#   'advancedError': ''},
#  {'secType': 'FUT',
#   'conId': 620730920,
#   'symbol': 'NQ',
#   'lastTradeDateOrContractMonth': '20240621',
#   'right': '?',
#   'multiplier': '20',
#   'exchange': 'CME',
#   'currency': 'USD',
#   'localSymbol': 'NQM4',
#   'tradingClass': 'NQ',
#   'orderId': 196,
#   'clientId': 69,
#   'permId': 196158479,
#   'action': 'SELL',
#   'totalQuantity': 1.0,
#   'orderType': 'LMT',
#   'lmtPrice': 19021.75,
#   'auxPrice': 0.0,
#   'tif': 'GTC',
#   'ocaType': 3,
#   'displaySize': 2147483647,
#   'rule80A': '0',
#   'openClose': '',
#   'volatilityType': 0,
#   'deltaNeutralOrderType': 'None',
#   'referencePriceType': 0,
#   'account': 'U10394496',
#   'clearingIntent': 'IB',
#   'adjustedOrderType': 'None',
#   'cashQty': 0.0,
#   'dontUseAutoPriceForHedge': True,
#   'status': 'Submitted',
#   'remaining': 1.0,
#   'fills': [],
#   'log': [{'time': datetime.datetime(2024, 5, 23, 19, 41, 18, 677537, tzinfo=datetime.timezone.utc),
#     'status': 'Submitted',
#     'message': '',
#     'errorCode': 0}],
#   'advancedError': ''},
#  {'secType': 'FUT',
#   'conId': 620730920,
#   'symbol': 'NQ',
#   'lastTradeDateOrContractMonth': '20240621',
#   'multiplier': '20',
#   'exchange': 'CME',
#   'currency': 'USD',
#   'localSymbol': 'NQM4',
#   'tradingClass': 'NQ',
#   'orderId': 399,
#   'clientId': 40,
#   'permId': 1735431450,
#   'action': 'BUY',
#   'totalQuantity': 1.0,
#   'orderType': 'LMT',
#   'lmtPrice': 18680.0,
#   'auxPrice': 0.0,
#   'account': 'U10394496',
#   'status': 'Submitted',
#   'remaining': 1.0,
#   'fills': [],
#   'log': [{'time': datetime.datetime(2024, 5, 23, 19, 57, 25, 252115, tzinfo=datetime.timezone.utc),
#     'status': 'PendingSubmit',
#     'message': '',
#     'errorCode': 0},
#    {'time': datetime.datetime(2024, 5, 23, 19, 57, 25, 874174, tzinfo=datetime.timezone.utc),
#     'status': 'Submitted',
#     'message': '',
#     'errorCode': 0}],
#   'advancedError': ''}]

# %%
trades = parse_ibrecords(ib.trades())
submittedTrades = [o for o in trades if o["status"] == "Submitted"]

print_ibrecords_table(
    submittedTrades,
    ["orderId", "permId", "status", "orderType", "action", "lmtPrice", "remaining"],
)
# Out:
#    orderId      permId     status orderType action  lmtPrice  remaining
# 0    311.0  1735429010  Submitted       LMT   SELL  18766.75        1.0
# 1    378.0  1735430610  Submitted       LMT    BUY  18670.25        1.0
# 2    379.0  1735430611  Submitted       LMT    BUY  18670.25        1.0
# 3      NaN  2099801404  Submitted       LMT    BUY  18040.50        1.0
# 4    334.0  1735429255  Submitted       LMT   SELL  18706.50        1.0
# 5    271.0   196158554  Submitted       LMT   SELL  18924.50        1.0
# 6    196.0   196158479  Submitted       LMT   SELL  19021.75        1.0
# 7    399.0  1735431450  Submitted       LMT    BUY  18680.00        1.0

# %%
def parse_ibrecords(data_array):

    data_list = []

    for obj in data_array:
        data = {}

        if hasattr(obj, "contract"):
            util.logging.debug(obj.contract)
            contract = util.dataclassNonDefaults(obj.contract)
            data = {**data, **contract}

        if hasattr(obj, "order"):
            util.logging.debug(obj.order)
            order = util.dataclassNonDefaults(obj.order)
            order.pop("softDollarTier")
            data = {**data, **order}

        if hasattr(obj, "orderStatus"):
            util.logging.debug(obj.orderStatus)
            orderStatus = util.dataclassNonDefaults(obj.orderStatus)
            data = {**data, **orderStatus}

        if hasattr(obj, "fills"):
            util.logging.debug(obj.fills)
            fills = {"fills": obj.fills}
            data = {**data, **fills}

        if hasattr(obj, "log"):
            util.logging.debug(obj.log)
            logs = {"log": [util.dataclassAsDict(e) for e in obj.log]}
            data = {**data, **logs}

        if hasattr(obj, "advancedError"):
            util.logging.debug(obj.advancedError)
            advancedError = {"advancedError": obj.advancedError}
            data = {**data, **advancedError}

        if type(obj) == Order:
            util.logging.debug(obj)
            order = util.dataclassNonDefaults(obj)
            order.pop("softDollarTier")
            data = {**data, **order}

        data_list.append(data)

    return data_list


def print_ibrecords_table(
    data_array,
    cols=[
        "localSymbol",
        "permId",
        "status",
        "orderType",
        "action",
        "lmtPrice",
        "remaining",
    ],
):
    df = pd.DataFrame(data_array)
    df = df[cols]
    print(df)


# openTrades = parse_ibrecords(ib.openTrades())
accountSummary = ib.accountSummary()
accountValues = ib.accountValues()

# openTrades = parse_ibrecords(ib.openTrades())
# # util.df([d for d in openTrades])

# print_ibrecords_table(openTrades)

# openOrders = parse_ibrecords(ib.openOrders())
# util.df([d for d in openOrders])

# trades = parse_ibrecords(ib.trades())
# util.df([d for d in trades])

# orders = parse_ibrecords(ib.orders())
# util.df([d for d in orders])


openOrders = parse_ibrecords(ib.openOrders())
openOrders

# %%
print_ibrecords_table(
    openOrders,
    cols=[
        "localSymbol",
        "permId",
        "status",
        "orderType",
        "action",
        "lmtPrice",
        "remaining",
    ],
)

# %%
ord = ib.orders()

[print(o) for o in ord if o.permId == 1394515162]

# %%
util.df(ib.orders())

# %%
util.df(ib.openOrders())

# %%
from datetime import datetime

input_string = "20240930 16:00:00 Central Standard Time"
date_format = "%Y%m%d %H:%M:%S %Z"

try:
    datetime_object = datetime.strptime(input_string, date_format)
    print(datetime_object)
except ValueError:
    print("Incorrect date format.")

# %%
util.df([t for t in ib.reqAllOpenOrders()])

# %%
clear_output()
o = ib.orders()[0]
o = util.dataclassNonDefaults(o)
o.pop("softDollarTier", None)
o.pop("shareholder", None)
o.pop("autoCancelDate", None)
o.pop("auxPrice", None)

data, count = supabase.table("orders").upsert(o).execute()

util.tree(o)

# %%
o["autoCancelDate"]

# %%
od = util.dataclassAsDict(o)
print(od)

# %%
clear_output()
o = ib.orders()[0]
od = util.dataclassAsDict(o)

data, count = supabase.table("orders").upsert(od).execute()

# %%
clear_output()
util.dataclassRepr(ib.trades()[0])

# util.dataclassAsDict(executions[0])

# %%
# Get Account details
details = ib.accountSummary()
details_df = util.df(details)

# Tag Values
# tags = details_df['tag'].values.tolist()
# print(tags)

# Set tag values as index
details_df = details_df.set_index("tag")
net_liquidation_value = details_df.loc["NetLiquidation", "value"]
details_df

# %%
util.tree(ib.trades()[0])

# %%
util.tree(ib.openTrades()[0])

# %%
util.tree(ib.openTrades()[1])

# %%
trades = ib.reqAllOpenOrders()

trades.sort(key=lambda trade: trade.order.lmtPrice)

for trade in trades:
    orderstatus = trade.orderStatus
    order = trade.order

    if trade.contract.symbol != "NQ":
        continue

    print(
        f"{trade.contract.symbol}\t{order.permId}\t{orderstatus.status}\t{order.action}\t{orderstatus.filled}\t{orderstatus.remaining}\t\t{order.lmtPrice}\t"
    )

# %%
trades_df = util.df(ib.trades())
trades_df

# %%
import sqlite3

# Create a connection to the SQLite database
conn = sqlite3.connect("trades.db")

# Create a cursor object to execute SQL queries
cursor = conn.cursor()

# Create the "trades" table if it doesn't exist
cursor.execute(
    """
    CREATE TABLE IF NOT EXISTS trades (
        contract TEXT,
        order TEXT,
        orderStatus TEXT,
        fills TEXT,
        log TEXT,
        advancedError TEXT
    )
"""
)

# Convert the DataFrame to a list of tuples
trades_data = trades_df.to_records(index=False).tolist()

# Insert the data into the "trades" table
cursor.executemany(
    """
    INSERT INTO trades (contract, order, orderStatus, fills, log, advancedError)
    VALUES (?, ?, ?, ?, ?, ?)
""",
    trades_data,
)

# Commit the changes and close the connection
conn.commit()
conn.close()

# %%
# get all the trades where fills is not []
fills = trades_df[trades_df.fills.map(len) > 0]

fills_list = list(fills["order"])

# loop through fills and convert each member of this data type to a row in a df
#  Order(permId=253828901, action='BUY', orderType='LMT', lmtPrice=17580.0, auxPrice=0.0, tif='GTC', ocaType=3, displaySize=2147483647, rule80A='0', openClose='', volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='U10394496', clearingIntent='IB', cashQty=0.0, dontUseAutoPriceForHedge=True, autoCancelDate='20240930 16:00:00 Central Standard Time', filledQuantity=1.0, refFuturesConId=2147483647, shareholder='Not an insider or substantial shareholder')
